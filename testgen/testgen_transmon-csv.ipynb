# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import scqubits as qubit
import scqubits.utils.plotting as plot

import numpy as np

# %%
N = 4    # arbitrary last index of the particular eigenstate to be used for comparison, i.e., use 0, 1, ..., N-1
M = 12   # number of evals to be compared

# %% [markdown]
# # Transmon qubit

# %%
CPB = qubit.Transmon(
    EJ=30.02,
    EC=1.2,
    ng=0.3,
    ncut=31
    )

# %%
TESTNAME = 'transmon_1.csv'

CPB.eigenvals(evals_count=M, filename='./data/' + TESTNAME)
# Out:
# array([-21.84381856,  -6.17518551,   8.01366695,  20.04897106,
#         30.54312385,  38.7071573 ,  54.55482909,  67.49323244,
#         90.05182723, 107.1140667 , 135.67852225, 156.68219246])

# %%
TESTNAME = 'transmon_2.csv'

evals, evecs = CPB.eigensys(evals_count=N,  filename='./data/' + TESTNAME)

# %%
TESTNAME = 'transmon_3'

ng_list = np.linspace(-2, 2, 100)
CPB.plot_evals_vs_paramvals('ng', ng_list, evals_count=5, subtract_ground=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Spectral data', style=ProgressStyle(description_width='in…
# (<Figure size 900x600 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1f635b8d208>)

# %%
TESTNAME = 'transmon_4.csv'

ng_list = np.linspace(-2, 2, 50)
tst = CPB.get_spectrum_vs_paramvals('ng', ng_list, evals_count=4, subtract_ground=False, get_eigenstates=True, filename='./data/' + TESTNAME)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Spectral data', max=50.0, style=ProgressStyle(description…

# %%
TESTNAME = 'transmon_5.csv'

nmat = CPB.matrixelement_table('n_operator', evecs=None, evals_count=10, filename='./data/' + TESTNAME)
plot.print_matrix(abs(nmat))
# Out:
# (<Figure size 900x600 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1f639409fc8>)

# %%
TESTNAME = 'transmon_6'

CPB.ng = 0.3
ej_vals = CPB.EJ * np.cos(np.linspace(-np.pi/2, np.pi/2, 40))
CPB.plot_evals_vs_paramvals('EJ', ej_vals, evals_count=4, subtract_ground=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Spectral data', max=40.0, style=ProgressStyle(description…
# (<Figure size 900x600 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d76e645548>)

# %%
TESTNAME = 'transmon_7'
    
CPB.plot_n_wavefunction(esys=None, which=1, mode='real')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2366d1072b0>)

# %%
TESTNAME = 'transmon_8'

CPB.plot_phi_wavefunction(esys=None, which=(0,2,6), mode='real')
CPB.plot_phi_wavefunction(esys=None, which=1, mode='abs_sqr')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2366d1d2ac8>)

# %%
TESTNAME = 'transmon_9'

CPB.plot_matrixelements('n_operator', evals_count=10)
# Out:
# (<Figure size 720x360 with 3 Axes>,
#  (<matplotlib.axes._subplots.Axes3DSubplot at 0x2366d1c7dd8>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x2366d1cd320>))

# %%
TESTNAME = 'transmon_10'

mat_data = CPB.matrixelement_table('n_operator')
plot.print_matrix(abs(mat_data))
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2366d37da20>)

# %%
TESTNAME = 'transmon_11'

fig, ax = CPB.plot_matelem_vs_paramvals('n_operator', 'ng', ng_list, select_elems=4, filename='./data/test')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Spectral data', max=50.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))

# %%
CPB.filewrite('./data/transmon-test.csv')

# %%
tst = qubit.utils.file_io.read('./data/transmon-test.csv')

# %%
print(tst)
# Out:
# TRANSMON
#  ———— PARAMETERS ————
# EJ	: 30.02
# EC	: 1.2
# ng	: 0.3
# ncut	: 31
# truncated_dim	: None
# Hilbert space dimension	: 63

# %% [markdown]
# # Read data back in

# %%
import scqubits.utils.file_io as file_io

# %%
specdata = file_io.read("./data/transmon_5.csv")
# Out:
# c:\users\drjen\pycharmprojects\scqubits\scqubits\utils\file_io.py:378: UserWarning: loadtxt: Empty input file: "./data/transmon_5_energy_table.csv"
#   data_array = np.loadtxt(filename)
